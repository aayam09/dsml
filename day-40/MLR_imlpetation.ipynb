# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
data_df = pd.read_csv("https://www.statlearning.com/s/Advertising.csv", index_col = 0)
data_df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
X = data_df[['TV','radio']].to_numpy()
Y = data_df[['sales']].to_numpy()

# %%
X.shape
# Out:
# (200, 2)

# %%
Y.shape
# Out:
# (200, 1)

# %%
X = np.concat((np.ones((200,1)), X), axis = 1)

# %%
beata = np.linalg.inv(np.dot(X.T,X)).dot(X.T).dot(Y)

# %%
beata = beata.flatten()

# %%
print(f"{beata[0]:.3f} + {beata[1]:.3f} * x1 + {beata[2]:.3f} * x2")
# Out:
# 2.921 + 0.046 * x1 + 0.188 * x2

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import  r2_score

# %%
X = data_df[['TV','radio','newspaper']].to_numpy()
Y = data_df[['sales']].to_numpy()

# %%
X_train, X_test, y_train, y_test  = train_test_split(X, Y, test_size=0.2, random_state=909)

# %%
linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear_reg.predict(X_test)

# %%
SSE = np.sum(np.power((y_test - y_pred), 2))
SSE
# Out:
# np.float64(82.41100233331818)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.928413953303882
